# %%
def print_characters(element):
    print element[0]
    print element[1]
    print element[2]
    print element[3]
    print element[4]

# %%
print_characters('fifth')
# Out:
# f
# i
# f
# t
# h

# %%
#works if characters in string match those defined in function e.g.
print_characters('follow')
#doesn't print last character as string islonger than function can take, but it still works
# Out:
# f
# o
# l
# l
# o

# %%
#e.g.
print_characters('four')
# Out:
# f
# o
# u
# r
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-9019c3733b73> in <module>()
#       1 #e.g.
# ----> 2 print_characters('four')
#
# <ipython-input-1-5a41e29ba1bb> in print_characters(element)
#       4     print element[2]
#       5     print element[3]
# ----> 6     print element[4]
#       7
#
# IndexError: string index out of range

# %%
#this throws an error as the string is shorter than the function expects

# %%
def print_characters(element):
    for letter in element:
        #this acts as a counter to count its way through the array. Don't forget the :
        print letter

# %%
print_characters('this is a long string to print')
# Out:
# t
# h
# i
# s
#
# i
# s
#
# a
#
# l
# o
# n
# g
#
# s
# t
# r
# i
# n
# g
#
# t
# o
#
# p
# r
# i
# n
# t

# %%
print_characters('short string')
# Out:
# s
# h
# o
# r
# t
#
# s
# t
# r
# i
# n
# g

# %%
print_characters('lo')
# Out:
# l
# o

# %%
test_list = [1,2,3,4,5]

# %%
print test_list
# Out:
# [1, 2, 3, 4, 5]

# %%
test_list1 = ['this','is','a','string']

# %%
print test_list1
# Out:
# ['this', 'is', 'a', 'string']

# %%
test_list2 = ['this', 'list', 'is','a','string','and','numbers','3','4','5']

# %%
print test_list2
# Out:
# ['this', 'list', 'is', 'a', 'string', 'and', 'numbers', '3', '4', '5']

# %%
print test_list2[3:8]
#prints 3rd-8th elements
# Out:
# ['a', 'string', 'and', 'numbers', '3']

# %%
test_list3 = ['hello','world']

# %%
print test_list3
# Out:
# ['hello', 'world']

# %%
test_list3 = ['hello','world','6']
#lists can be edited

# %%
print test_list3
# Out:
# ['hello', 'world', '6']

# %%
test_list3.remove('world')
#can remove elements from a list

# %%
print test_list3
# Out:
# ['hello', '6']

# %%
import glob

# %%
print glob.glob('*.csv')
#will return a LIST of absolute paths or paths relative to where I am (as in this case - same directory)
# Out:
# ['inflammation-01.csv', 'inflammation-02.csv', 'inflammation-03.csv', 'inflammation-04.csv', 'inflammation-05.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-08.csv', 'inflammation-09.csv', 'inflammation-10.csv', 'inflammation-11.csv', 'inflammation-12.csv', 'small-01.csv', 'small-02.csv', 'small-03.csv']

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def analyze(filename):
    '''reads in data from an inflammation file and prints the mean, maximum and minimum daily inflammation across all patients'''   
    filelist = glob.glob('inf*.csv')
            
        data = np.loadtxt(filename, delimiter=',')

        plt.figure(figsize=(10.0,3.0))

        plt.subplot(1,3,1)
        plt.xlabel("Average Inflammation")
        plt.plot(data.mean(axis=0))

        plt.subplot(1,3,2)
        plt.xlabel("Minimum Inflammation")
        plt.plot(data.min(axis=0))

        plt.subplot(1,3,3)
        plt.xlabel("Maximum Inflammation")
        plt.plot(data.max(axis=0))

        plt.tight_layout()
        #tells the programme to keep white space around graphs to a minimum
        plt.show()
# Out:
#   File "<ipython-input-75-a752a24a5e4e>", line 6
#     data = np.loadtxt(filename, delimiter=',')
#     ^
# IndentationError: unexpected indent

# %%
analyze(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-5bb5d4b185d7> in <module>()
# ----> 1 analyze(filename)
#
# NameError: name 'filename' is not defined

# %%
filelist = glob.glob('*.csv')

# %%
print filelist
# Out:
# ['inflammation-01.csv', 'inflammation-02.csv', 'inflammation-03.csv', 'inflammation-04.csv', 'inflammation-05.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-08.csv', 'inflammation-09.csv', 'inflammation-10.csv', 'inflammation-11.csv', 'inflammation-12.csv', 'small-01.csv', 'small-02.csv', 'small-03.csv']

# %%
list = glob.glob('inf*.csv')

# %%
print filelist[0]
# Out:
# inflammation-01.csv

# %%
analyze(filelist[0])

# %%
for file in filelist:
    analyze(file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-6cff406ec7ed> in <module>()
#       1 for file in filelist:
# ----> 2     analyze(file)
#
# <ipython-input-69-dd6cd16fbbad> in analyze(filename)
#      24         plt.tight_layout()
#      25         #tells the programme to keep white space around graphs to a minimum
# ---> 26         plt.show()
#
# c:\Anaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     152     """
#     153     global _show
# --> 154     return _show(*args, **kw)
#     155
#     156
#
# c:\Anaconda\lib\site-packages\IPython\kernel\zmq\pylab\backend_inline.py in show(close)
#      41     try:
#      42         for figure_manager in Gcf.get_all_fig_managers():
# ---> 43             display(figure_manager.canvas.figure)
#      44     finally:
#      45         show._to_draw = []
#
# ...

# %%
print filelist
# Out:
# ['inflammation-01.csv', 'inflammation-02.csv', 'inflammation-03.csv', 'inflammation-04.csv', 'inflammation-05.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-08.csv', 'inflammation-09.csv', 'inflammation-10.csv', 'inflammation-11.csv', 'inflammation-12.csv', 'small-01.csv', 'small-02.csv', 'small-03.csv']

# %%
def analyze(filename):
    '''reads in data from an inflammation file and prints the mean, maximum and minimum daily inflammation across all patients'''
    data = np.loadtxt(filename, delimiter=',')
    
    plt.figure(figsize=(10.0,3.0))
    
    plt.subplot(1,3,1)
    plt.xlabel("Average Inflammation")
    plt.plot(data.mean(axis=0))

    plt.subplot(1,3,2)
    plt.xlabel("Minimum Inflammation")
    plt.plot(data.min(axis=0))

    plt.subplot(1,3,3)
    plt.xlabel("Maximum Inflammation")
    plt.plot(data.max(axis=0))

    plt.tight_layout()
    #tells the programme to keep white space around graphs to a minimum
    plt.show()

# %%
for file in list:
    analyze(file)
